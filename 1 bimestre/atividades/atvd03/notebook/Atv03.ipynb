// %% [markdown]
// # Atv03

// %% [markdown]
// Usando a classe JOptionPane para entrada de dados, receba a nota de duas provas e de um trabalho.

// %%
import javax.swing.JOptionPane;
String aux;
float nota1, nota2, notaTrab;
aux = JOptionPane.showInputDialog("Digite a nota da primeira prova: ");
nota1 = Float.parseFloat(aux);
aux = JOptionPane.showInputDialog("Digite a nota da segunda prova: ");
nota2 = Float.parseFloat(aux);
aux = JOptionPane.showInputDialog("Digite a nota do trabalho: ");
notaTrab = Float.parseFloat(aux);
// Out:
// ERROR: java.awt.HeadlessException:
// No X11 DISPLAY variable was set, but this program performed an operation which requires it.

// %% [markdown]
// Calcule a média

// %%
double media = ((nota1 + nota2 + notaTrab)/3);
// Out:
// cannot find symbol
//   symbol:   variable nota1
//   location: class com.twosigma.beaker.javash.bkr3788271e.BeakerWrapperClass1261714175Id6cdeeda6e63c4922b16c99d46abf1382
//  double media = ((nota1 + nota2 + notaTrab)/3)
//                   ^    ^
//
// cannot find symbol
//   symbol:   variable nota2
//   location: class com.twosigma.beaker.javash.bkr3788271e.BeakerWrapperClass1261714175Id6cdeeda6e63c4922b16c99d46abf1382
//  double media = ((nota1 + nota2 + notaTrab)/3)
//                           ^    ^
//
// cannot find symbol
//   symbol:   variable notaTrab
//   location: class com.twosigma.beaker.javash.bkr3788271e.BeakerWrapperClass1261714175Id6cdeeda6e63c4922b16c99d46abf1382
// uble media = ((nota1 + nota2 + notaTrab)/3)
//                                ^       ^

// %% [markdown]
// Mostre a média usando o showMessageDialog da classe JOptionPane

// %%
double media = ((nota1 + nota2 + notaTrab)/3);
JOptionPane.showMessageDialog(null, "Media = " + media);
// Out:
// cannot find symbol
//   symbol:   variable nota1
//   location: class com.twosigma.beaker.javash.bkr3788271e.BeakerWrapperClass1261714175Id9513bd98b1f64e98b2c1ff6b61c78969
//  double media = ((nota1 + nota2 + notaTrab)/3)
//                   ^    ^
//
// cannot find symbol
//   symbol:   variable nota2
//   location: class com.twosigma.beaker.javash.bkr3788271e.BeakerWrapperClass1261714175Id9513bd98b1f64e98b2c1ff6b61c78969
//  double media = ((nota1 + nota2 + notaTrab)/3)
//                           ^    ^
//
// cannot find symbol
//   symbol:   variable notaTrab
//   location: class com.twosigma.beaker.javash.bkr3788271e.BeakerWrapperClass1261714175Id9513bd98b1f64e98b2c1ff6b61c78969
// uble media = ((nota1 + nota2 + notaTrab)/3)
//                                ^       ^
//
// cannot find symbol
//   symbol:   variable JOptionPane
//   location: class com.twosigma.beaker.javash.bkr3788271e.BeakerWrapperClass1261714175Id9513bd98b1f64e98b2c1ff6b61c78969
//  JOptionPane.showMessageDialog(null, "Medi
//  ^          ^
